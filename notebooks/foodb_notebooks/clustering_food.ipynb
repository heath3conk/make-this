# %% [markdown]
# # Create clustering model(s)
# - start with the "food.csv"
# - tfidf vectorizer & kmeans
# - combining text fields & attempting unsupervised kmeans model
# - combining text fields except for

# %%
# import pprint
import numpy as np
import pandas as pd

# import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans
# from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, make_scorer
from sklearn.feature_extraction.text import TfidfVectorizer
# from wordcloud import WordCloud

# %%
food = pd.read_csv("data/foodb_2020_04_07_csv/Food.csv")
food.head(3)
# Out:
#    id           name                 name_scientific  \
# 0   1       Angelica                Angelica keiskei
# 1   2  Savoy cabbage  Brassica oleracea var. sabauda
# 2   3  Silver linden                  Tilia argentea
#
#                                          description   itis_id  \
# 0  Angelica is a genus of about 60 species of tal...       NaN
# 1  Savoy cabbage (Brassica oleracea convar. capit...       NaN
# 2  Tilia tomentosa (Silver Lime in the UK and Sil...  845789.0
#
#       wikipedia_id picture_file_name picture_content_type  picture_file_size  \
# 0         Angelica             1.jpg           image/jpeg           111325.0
# 1    Savoy cabbage             2.jpg           image/jpeg           155178.0
# 2  Tilia tomentosa             3.jpg           image/jpeg            56367.0
#
#         picture_updated_at  ...  food_type               created_at  \
# 0  2012-04-20 09:29:57 UTC  ...     Type 1  2011-02-09 00:37:14 UTC
# 1  2012-04-20 09:39:54 UTC  ...     Type 1  2011-02-09 00:37:15 UTC
# 2  2012-04-20 09:41:25 UTC  ...     Type 1  2011-02-09 00:37:15 UTC
#
#                 updated_at creator_id updater_id export_to_afcdb  category  \
# 0  2019-05-14 18:04:13 UTC        NaN        2.0           False  specific
# 1  2019-05-14 18:04:13 UTC        NaN        NaN           False  specific
# 2  2019-05-17 16:19:45 UTC        NaN        NaN           False  specific
#
#    ncbi_taxonomy_id  export_to_foodb  public_id
# 0          357850.0             True  FOOD00001
# 1         1216010.0             True  FOOD00002
# 2               NaN             True  FOOD00003
#
# [3 rows x 23 columns]

# %%
rows = food.shape[0]
print(f"rows: {rows}")
print(f"columns: {food.columns}")
# Out:
# rows: 992
# columns: Index(['id', 'name', 'name_scientific', 'description', 'itis_id',
#        'wikipedia_id', 'picture_file_name', 'picture_content_type',
#        'picture_file_size', 'picture_updated_at', 'legacy_id', 'food_group',
#        'food_subgroup', 'food_type', 'created_at', 'updated_at', 'creator_id',
#        'updater_id', 'export_to_afcdb', 'category', 'ncbi_taxonomy_id',
#        'export_to_foodb', 'public_id'],
#       dtype='object')

# %%
# getting rid of columns I don"t care about
drop_columns = ["id", "itis_id", "picture_file_name", "picture_content_type", "picture_file_size", "picture_updated_at", "legacy_id", "created_at", "updated_at", "creator_id",
       "updater_id", "export_to_afcdb", "category", "ncbi_taxonomy_id", "export_to_foodb", "public_id"]

print(f"keeping columns: {set(food.columns).difference(set(drop_columns))}")
# Out:
# keeping columns: {'food_subgroup', 'wikipedia_id', 'food_type', 'name', 'description', 'name_scientific', 'food_group'}

# %%
food.drop(columns=drop_columns, inplace=True)
food.head(3)
# Out:
#             name                 name_scientific  \
# 0       Angelica                Angelica keiskei
# 1  Savoy cabbage  Brassica oleracea var. sabauda
# 2  Silver linden                  Tilia argentea
#
#                                          description     wikipedia_id  \
# 0  Angelica is a genus of about 60 species of tal...         Angelica
# 1  Savoy cabbage (Brassica oleracea convar. capit...    Savoy cabbage
# 2  Tilia tomentosa (Silver Lime in the UK and Sil...  Tilia tomentosa
#
#          food_group food_subgroup food_type
# 0  Herbs and Spices         Herbs    Type 1
# 1        Vegetables      Cabbages    Type 1
# 2  Herbs and Spices         Herbs    Type 1

# %%
null_count = {}
for col in food.columns:
    null_count[col] = round(food[col].isna().sum()/rows, 4)
    
null_count
# Out:
# {'name': 0.0,
#  'name_scientific': 0.3196,
#  'description': 0.0474,
#  'wikipedia_id': 0.1401,
#  'food_group': 0.003,
#  'food_subgroup': 0.0071,
#  'food_type': 0.0}

# %%
food.dropna(subset=["description"], inplace=True)
food.shape
# Out:
# (945, 7)

# %%
food.loc[food["food_type"] == "Type 1"].head(20)
# Out:
#              name                 name_scientific  \
# 0        Angelica                Angelica keiskei
# 1   Savoy cabbage  Brassica oleracea var. sabauda
# 2   Silver linden                  Tilia argentea
# 3            Kiwi             Actinidia chinensis
# 4          Allium                          Allium
# 5    Garden onion                     Allium cepa
# 6            Leek                   Allium porrum
# 7          Garlic                  Allium sativum
# 8          Chives            Allium schoenoprasum
# 9   Lemon verbena               Aloysia triphylla
# 10     Cashew nut          Anacardium occidentale
# 11      Pineapple                  Ananas comosus
# 12           Dill              Anethum graveolens
# 13  Custard apple               Annona reticulata
# 14    Wild celery                Apium graveolens
# 15         Peanut                Arachis hypogaea
# 16        Burdock                   Arctium lappa
# 17    Horseradish             Armoracia rusticana
# 18       Tarragon           Artemisia dracunculus
# 19        Mugwort              Artemisia vulgaris
#
#                                           description  \
# 0   Angelica is a genus of about 60 species of tal...
# 1   Savoy cabbage (Brassica oleracea convar. capit...
# 2   Tilia tomentosa (Silver Lime in the UK and Sil...
# 3   The kiwifruit, often shortened to kiwi in many...
# 4   Allium haematochiton is a species of wild onio...
# 5   The onion (Allium cepa) (Latin 'cepa' = onion)...
# 6   The leek is a vegetable that belongs, along wi...
# 7   With a history of human use of over 7,000 year...
# 8   Chives is the common name of Allium schoenopra...
# 9   Aloysia citrodora is a species of flowering pl...
# 10  The cashew, or caju, is a small tree native to...
# 11  The Pineapple (Ananas comosus), named for its ...
# 12  Dill (Anethum graveolens), also known as Lao c...
# 13  Custard apple, is a common name for a fruit, a...
# 14  Wild celery is a common name for several plant...
# 15  The peanut, also known as the groundnut and th...
# 16  Arctium lappa, commonly called greater burdock...
# 17  Horseradish (Armoracia rusticana, syn. Cochlea...
# 18  Tarragon (Artemisia dracunculus) is a species ...
# 19  Mugwort (Artemisia vulgaris), or common wormwo...
#
#                     wikipedia_id        food_group            food_subgroup  \
# 0                       Angelica  Herbs and Spices                    Herbs
# 1                  Savoy cabbage        Vegetables                 Cabbages
# 2                Tilia tomentosa  Herbs and Spices                    Herbs
# 3                      Kiwifruit            Fruits          Tropical fruits
# 4           Allium haematochiton        Vegetables  Onion-family vegetables
# 5                          Onion        Vegetables  Onion-family vegetables
# 6                           Leek        Vegetables  Onion-family vegetables
# 7                         Garlic  Herbs and Spices                    Herbs
# 8                         Chives  Herbs and Spices                    Herbs
# 9              Aloysia citrodora  Herbs and Spices                    Herbs
# 10                    Cashew_nut              Nuts                     Nuts
# 11                     Pineapple            Fruits          Tropical fruits
# 12                          Dill  Herbs and Spices                    Herbs
# 13                 Custard apple            Fruits          Tropical fruits
# 14                   Wild celery  Herbs and Spices                   Spices
# 15                    Mr. Peanut              Nuts                     Nuts
# 16                 Arctium_lappa        Vegetables          Root vegetables
# 17                   Horseradish  Herbs and Spices                   Spices
# 18         Artemisia_dracunculus  Herbs and Spices                    Herbs
# 19  List of plants named mugwort  Herbs and Spices                    Herbs
#
#    food_type
# 0     Type 1
# 1     Type 1
# 2     Type 1
# 3     Type 1
# 4     Type 1
# 5     Type 1
# 6     Type 1
# 7     Type 1
# 8     Type 1
# 9     Type 1
# 10    Type 1
# 11    Type 1
# 12    Type 1
# 13    Type 1
# 14    Type 1
# 15    Type 1
# 16    Type 1
# 17    Type 1
# 18    Type 1
# 19    Type 1

# %%
food.loc[food["food_type"] == "Type 2"].head(20)
# Out:
#                  name name_scientific  \
# 267              Beer             NaN
# 268       Other bread             NaN
# 269  Breakfast cereal             NaN
# 272             Pasta             NaN
# 273           Biscuit             NaN
# 274         Sourdough             NaN
# 276    Fortified wine             NaN
# 611        Grape wine             NaN
# 614       Apple cider             NaN
# 615            Liquor             NaN
# 616            Cheese             NaN
# 617        Milk (Cow)             NaN
# 619            Yogurt             NaN
# 621             Vodka             NaN
# 622            Whisky             NaN
# 623         Ice cream             NaN
# 624               Gin             NaN
# 625             Honey             NaN
# 626         Liquorice             NaN
# 627           Vinegar             NaN
#
#                                            description      wikipedia_id  \
# 267  Beer is an alcoholic beverage produced by the ...              Beer
# 268  Bread is the staple food in Europe, European-d...             Bread
# 269  A breakfast cereal (or just cereal) is a food ...  Breakfast cereal
# 272  Pasta is a type of noodle and is a staple food...             Pasta
# 273  A biscuit is a baked, commonly flour-based foo...           Biscuit
# 274  Sourdough is a dough containing a Lactobacillu...         Sourdough
# 276  Fortified wine is wine with an added distilled...    Fortified wine
# 611  Wine is an alcoholic beverage made from fermen...        Grape_wine
# 614  Apple cider (also called sweet cider or soft c...       Apple_cider
# 615  A distilled beverage, spirit, liquor, or hard ...            Liquor
# 616  Cheese is a food derived from milk that is pro...            Cheese
# 617  As an agricultural product, milk is extracted ...              Milk
# 619  Yogurt, yoghurt, or yoghourt is a fermented mi...               NaN
# 621  Vodka is a distilled beverage composed primari...             Vodka
# 622  Whisky or whiskey is a type of distilled alcoh...            Whisky
# 623  Ice cream (derived from earlier iced cream or ...         Ice_cream
# 624  Gin is a spirit which derives its predominant ...               Gin
# 625  Honey is a sweet food made by bees using necta...             Honey
# 626  Liquorice or licorice is the root of Glycyrrhi...         Liquorice
# 627  Vinegar is a liquid consisting mainly of aceti...           Vinegar
#
#                       food_group            food_subgroup food_type
# 267                    Beverages      Fermented beverages    Type 2
# 268  Cereals and cereal products             Other breads    Type 2
# 269  Cereals and cereal products          Cereal products    Type 2
# 272  Cereals and cereal products          Cereal products    Type 2
# 273  Cereals and cereal products          Cereal products    Type 2
# 274  Cereals and cereal products                   Doughs    Type 2
# 276                    Beverages          Fortified wines    Type 2
# 611                    Beverages      Fermented beverages    Type 2
# 614                    Beverages      Fermented beverages    Type 2
# 615                    Beverages      Distilled beverages    Type 2
# 616       Milk and milk products  Fermented milk products    Type 2
# 617       Milk and milk products        Unfermented milks    Type 2
# 619       Milk and milk products  Fermented milk products    Type 2
# 621                    Beverages      Distilled beverages    Type 2
# 622                    Beverages      Distilled beverages    Type 2
# 623              Confectioneries          Frozen desserts    Type 2
# 624                    Beverages      Distilled beverages    Type 2
# 625              Confectioneries    Other confectioneries    Type 2
# 626              Confectioneries                  Candies    Type 2
# 627                 Baking goods               Seasonings    Type 2

# %%
food["food_type"].value_counts()
# Out:
# food_type
# Type 1     693
# Type 2     235
# Unknown     17
# Name: count, dtype: int64

# %%
food.loc[(food["food_type"] == "Type 2") & (food["name_scientific"].isna())].shape
# Out:
# (232, 7)

# %%
food.loc[(food["food_type"] == "Type 1") & (food["name_scientific"].isna())].shape
# Out:
# (34, 7)

# %% [markdown]
# - So *most* of the scientific names for "Type 2" foods are null and *few* are null for "Type 1" foods...
# - They don"t mention the "food_type" field on their [schema reference](https://foodb.ca/schema) page so I don"t know exactly how they"ve arrived at these labels. In that display of the first 20 rows where `food_type == "Type 2"` they"re mostly manufactured foods like beer, bread & breakfast cereal but then there"s also honey so maybe they"re counting bees as cooks?
# - whatever that label means, I"m going to leave it out

# %%
food.drop(columns=["food_type"], axis=1, inplace=True)
food.columns
# Out:
# Index(['name', 'name_scientific', 'description', 'wikipedia_id', 'food_group',
#        'food_subgroup'],
#       dtype='object')

# %%
# get rid of those "nan" values prior to combining all the text
food.fillna("", inplace=True)

# source: https://sparkbyexamples.com/pandas/pandas-combine-two-columns-of-text-in-dataframe/
food["all_text"] = food[food.columns].apply(" ".join, axis=1)
food["all_text"].head(5)
# Out:
# 0    Angelica Angelica keiskei Angelica is a genus ...
# 1    Savoy cabbage Brassica oleracea var. sabauda S...
# 2    Silver linden Tilia argentea Tilia tomentosa (...
# 3    Kiwi Actinidia chinensis The kiwifruit, often ...
# 4    Allium Allium Allium haematochiton is a specie...
# Name: all_text, dtype: object

# %% [markdown]
# ---
# ## TFIDF Vectorizer & unsupervised KMeans
# - let's see how we do if we just throw the text in "food_group" and "food_subgroup" into a block with all the other text fields

# %%
tvec = TfidfVectorizer()  # starting with the defaults
tvec_df = pd.DataFrame(tvec.fit_transform(food["all_text"]).todense(), columns=tvec.get_feature_names_out())

# plot top occuring words
tvec_df.sum().sort_values(ascending=False).head(10).plot(kind="barh", title="top 10 words, no stops removed");

# %%
tvec_1 = TfidfVectorizer(stop_words="english")
tvec_df_1 = pd.DataFrame(tvec_1.fit_transform(food["all_text"]).todense(), columns=tvec_1.get_feature_names_out())

# plot top occuring words
tvec_df_1.sum().sort_values(ascending=False).head(10).plot(kind="barh", title="top 10 words, English stops removed");

# %%
# these next cells about kmeans are based on lesson 2.21
km = KMeans(n_init="auto", random_state=42)
km.fit(tvec_df_1)
# Out:
# KMeans(random_state=42)

# %%
# 8 is the default for `n_clusters`
len(km.cluster_centers_)
# Out:
# 8

# %%
food["cluster"] = km.labels_
food.head(10)
# Out:
#             name                 name_scientific  \
# 0       Angelica                Angelica keiskei
# 1  Savoy cabbage  Brassica oleracea var. sabauda
# 2  Silver linden                  Tilia argentea
# 3           Kiwi             Actinidia chinensis
# 4         Allium                          Allium
# 5   Garden onion                     Allium cepa
# 6           Leek                   Allium porrum
# 7         Garlic                  Allium sativum
# 8         Chives            Allium schoenoprasum
# 9  Lemon verbena               Aloysia triphylla
#
#                                          description          wikipedia_id  \
# 0  Angelica is a genus of about 60 species of tal...              Angelica
# 1  Savoy cabbage (Brassica oleracea convar. capit...         Savoy cabbage
# 2  Tilia tomentosa (Silver Lime in the UK and Sil...       Tilia tomentosa
# 3  The kiwifruit, often shortened to kiwi in many...             Kiwifruit
# 4  Allium haematochiton is a species of wild onio...  Allium haematochiton
# 5  The onion (Allium cepa) (Latin 'cepa' = onion)...                 Onion
# 6  The leek is a vegetable that belongs, along wi...                  Leek
# 7  With a history of human use of over 7,000 year...                Garlic
# 8  Chives is the common name of Allium schoenopra...                Chives
# 9  Aloysia citrodora is a species of flowering pl...     Aloysia citrodora
#
#          food_group            food_subgroup  \
# 0  Herbs and Spices                    Herbs
# 1        Vegetables                 Cabbages
# 2  Herbs and Spices                    Herbs
# 3            Fruits          Tropical fruits
# 4        Vegetables  Onion-family vegetables
# 5        Vegetables  Onion-family vegetables
# 6        Vegetables  Onion-family vegetables
# 7  Herbs and Spices                    Herbs
# 8  Herbs and Spices                    Herbs
# 9  Herbs and Spices                    Herbs
#
#                                             all_text  cluster
# 0  Angelica Angelica keiskei Angelica is a genus ...        5
# 1  Savoy cabbage Brassica oleracea var. sabauda S...        4
# 2  Silver linden Tilia argentea Tilia tomentosa (...        5
# 3  Kiwi Actinidia chinensis The kiwifruit, often ...        2
# 4  Allium Allium Allium haematochiton is a specie...        5
# 5  Garden onion Allium cepa The onion (Allium cep...        5
# 6  Leek Allium porrum The leek is a vegetable tha...        5
# 7  Garlic Allium sativum With a history of human ...        4
# 8  Chives Allium schoenoprasum Chives is the comm...        5
# 9  Lemon verbena Aloysia triphylla Aloysia citrod...        5

# %%
food["cluster"].value_counts(normalize=True)
# Out:
# cluster
# 5    0.275132
# 4    0.192593
# 0    0.143915
# 2    0.128042
# 1    0.123810
# 7    0.070899
# 3    0.043386
# 6    0.022222
# Name: proportion, dtype: float64

# %%
food.loc[food["cluster"] == 6][["name", "description"]].head(20)
# aside from jicama, which I don't think I would have grouped with legumes, these top 20 seem legit
# Out:
#                 name                                        description
# 46          Chickpea  The chickpea (Cicer arietinum) is a legume of ...
# 84          Soy bean  The soybean (US) or soya bean (UK) (Glycine ma...
# 131     Scarlet bean  Phaseolus coccineus, known as runner bean, sca...
# 132        Lima bean  Phaseolus lunatus is a legume. It is grown for...
# 133      Common bean  Phaseolus vulgaris, the common bean, string be...
# 196       Broad bean  Vicia faba, also known as the broad bean, fava...
# 197      Adzuki bean  The azuki bean, also known as adzuki or aduki,...
# 198        Gram bean  Vigna mungo, known as Urad Dal, black gram, bl...
# 199        Mung bean  The mung or moong bean (also known as green gr...
# 380    Hyacinth bean  Lablab purpureus, commonly known as the hyacin...
# 409        Moth bean  Vigna aconitifolius, called the moth bean, mat...
# 506      Winged bean  The Winged bean (Psophocarpus tetragonolobus),...
# 508           Jicama  Pachyrhizus erosus, commonly known as jicama, ...
# 522   Black-eyed pea  The black-eyed pea or black-eyed bean, a legum...
# 539    Yardlong bean  Vigna unguiculata subsp. sesquipedalis is a le...
# 620             Bean  Bean is a common name for large plant seeds us...
# 705      Baked beans  Baked beans is a dish containing beans, someti...
# 866           Pulses  A pulse (Latin "puls", from Ancient Greek πόλτ...
# 881  Yellow wax bean  Yellow Wax beans are a member of the <i>Fabace...
# 882       Green bean  Green beans, also known as string beans, snap ...

# %%
km.inertia_
# Out:
# 893.3201000631061

# %%
silhouette_score(tvec_df_1, km.labels_)
# Out:
# 0.014305703070228857

# %% [markdown]
# ### observations on first iteration
# - high inertia
# - low silhouette score

# %% [markdown]
# ## grid search

# %%
stops = list(TfidfVectorizer(stop_words="english").get_stop_words())

pipe_params = {
    "tfidf__stop_words": [None, stops],
    "tfidf__max_features": [None, 250, 300],
    "tfidf__min_df": [1, 0.01, 0.05],
    "tfidf__max_df": [1.0, 0.98, 0.95, 0.9],
    "tfidf__ngram_range": [(1,1), (1,2), (1,3)],
    "kmeans__n_clusters": range(3,11)
}

pipeline = Pipeline([("tfidf", TfidfVectorizer()), ("kmeans", KMeans(n_init="auto"))])

# %% [markdown]
# - see [sklearn docs](https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter) for available scorers
# - the problem with all of these scorers is that they require "true" labels & this is unsupervised so I'm making a manual grid search; this also comes from lesson 2.21
# - variations I've tried that didn't have any/much effect on the scores or that generated low enough scores that I left them out of further iterations:
#     - <u>kmeans params</u>:
#         - low values for `k` were consistently worse than higher values; I initially started with `k=range(3,11)`
#         - `algorithm="elkan"` generated the same scores as the default `algorithm="lloyd`
#     - <u>tfidf params</u>:
#         - no stop words: the max silhouette score was consistently vectorized with stop words

# %%
scores_no_stops = []
for k in range(3, 21):
    vect = TfidfVectorizer()  # defaults again
    vect_df = pd.DataFrame(vect.fit_transform(food["all_text"]).todense(), columns=vect.get_feature_names_out())
    
    model = KMeans(n_clusters=k, n_init="auto", random_state=42)
    model.fit(vect_df)
    
    score = silhouette_score(vect_df, model.labels_)
    scores_no_stops.append([k, model.inertia_, score])

# %%
scores_df = pd.DataFrame(scores_no_stops, columns=["k", "inertia", "silhouette_score"])

# %%
scores_df.tail()
# Out:
#      k     inertia  silhouette_score
# 13  16  837.896867          0.019994
# 14  17  833.508423          0.022007
# 15  18  830.900203          0.022680
# 16  19  828.100412          0.023038
# 17  20  824.248783          0.024871

# %%
def custom_kmeans_grid_search(data: pd.Series, clusters: list[int], stops=[None, "english"]) -> pd.DataFrame:
    scores = []
    for option in stops:
        vect = TfidfVectorizer(stop_words=option)
        vect_df = pd.DataFrame(vect.fit_transform(data).todense(), columns=vect.get_feature_names_out())
        
        for k in clusters:
            model = KMeans(n_clusters=k, n_init="auto", random_state=42)
            model.fit(vect_df)
            
            score = silhouette_score(vect_df, model.labels_)
            scores.append([option, k, model.inertia_, score])
    
    return pd.DataFrame(scores, columns=["stop_words", "k", "inertia", "silhouette_score"])

# %%
trial_1 = custom_kmeans_grid_search(food["all_text"], clusters=range(20, 31), stops=pipe_params["tfidf__stop_words"])

# %%
trial_1.loc[trial_1["silhouette_score"] == max(trial_1["silhouette_score"])]
# Out:
#                                            stop_words   k     inertia  \
# 20  [hers, take, give, so, now, here, three, anywh...  29  839.202973
#
#     silhouette_score
# 20          0.027072

# %%
trial_2 = custom_kmeans_grid_search(food["all_text"], clusters=range(30, 46), stops=[stops])
trial_2.loc[trial_2["silhouette_score"] == max(trial_2["silhouette_score"])]
# Out:
#                                           stop_words   k     inertia  \
# 2  [hers, take, give, so, now, here, three, anywh...  32  832.743965
#
#    silhouette_score
# 2           0.02704
